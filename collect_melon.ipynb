# %%
# https://www.melon.com/genre/song_list.htm?gnrCode=GN0500
# https://www.melon.com/song/detail.htm?songId=38427225

# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import os
from tqdm import tqdm
import time
import random
import numpy as np

# %%
headers = {
    'User-Agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/68.0.3440.75 Safari/537.36')
}

gnr_url = "https://www.melon.com/genre/song_list.htm"

params = {
    'gnrCode': 'GN0500',
}

response = requests.get(gnr_url, params=params, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
song_list = soup.select('.wrap_song_info')

# %%
print(song_list)
# Out:
# [<div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427225);" title="어떻게든 이별 재생">어떻게든 이별</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('105031');" title="참깨와 솜사탕 - 페이지 이동">참깨와 솜사탕</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('105031');" title="참깨와 솜사탕 - 페이지 이동">참깨와 솜사탕</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685326');" title="어떻게든 이별 - 페이지 이동">어떻게든 이별</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427129);" title="us 재생">us</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2620722');" title="잭킹콩 (JKC) - 페이지 이동">잭킹콩 (JKC)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2620722');" title="잭킹콩 (JKC) - 페이지 이동">잭킹콩 (JKC)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685293');" title="us - 페이지 이동">us</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427908);" title="보통의 이야기 재생">보통의 이야기</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('873850');" title="소보 - 페이지 이동">소보</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('873850');" title="소보 - 페이지 이동">소보</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685437');" title="보통의 이야기 - 페이지 이동">보통의 이야기</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426242);" title="엔딩샷 (Ending Shot) 재생">엔딩샷 (Ending Shot)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('967168');" title="정가이 (와인루프) - 페이지 이동">정가이 (와인루프)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('967168');" title="정가이 (와인루프) - 페이지 이동">정가이 (와인루프)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685083');" title="엔딩샷 (Ending Shot) - 페이지 이동">엔딩샷 (Ending Shot)</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38425552);" title="If 재생">If</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('730563');" title="비버 (Beaver) - 페이지 이동">비버 (Beaver)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('730563');" title="비버 (Beaver) - 페이지 이동">비버 (Beaver)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684989');" title="If - 페이지 이동">If</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427146);" title="잘자요 재생">잘자요</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('1133834');" title="같은장르 - 페이지 이동">같은장르</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1133834');" title="같은장르 - 페이지 이동">같은장르</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685308');" title="잘자요 - 페이지 이동">잘자요</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426831);" title="유영 재생">유영</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2738135');" title="유현곤 - 페이지 이동">유현곤</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2738135');" title="유현곤 - 페이지 이동">유현곤</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685196');" title="유영 - 페이지 이동">유영</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38429177);" title="Our Time 재생">Our Time</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088919');" title="나승우 - 페이지 이동">나승우</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088919');" title="나승우 - 페이지 이동">나승우</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685780');" title="TIMELESS - 페이지 이동">TIMELESS</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38429150);" title="첫눈에 반해버린 찐따 재생">첫눈에 반해버린 찐따</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2084986');" title="VINCI - 페이지 이동">VINCI</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2084986');" title="VINCI - 페이지 이동">VINCI</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685779');" title="첫눈에 반해버린 찐따 - 페이지 이동">첫눈에 반해버린 찐따</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38429132);" title="널 보고 싶지 않은 밤 재생">널 보고 싶지 않은 밤</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3192119');" title="Millez - 페이지 이동">Millez</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3192119');" title="Millez - 페이지 이동">Millez</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685771');" title="널 보고 싶지 않은 밤 - 페이지 이동">널 보고 싶지 않은 밤</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38428982);" title="우리의 사랑 재생">우리의 사랑</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('856446');" title="박치용 - 페이지 이동">박치용</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('856446');" title="박치용 - 페이지 이동">박치용</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685706');" title="우리의 사랑 - 페이지 이동">우리의 사랑</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38428981);" title="당신은 날 가르치지 않았죠 재생">당신은 날 가르치지 않았죠</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3881937');" title="윈린 - 페이지 이동">윈린</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3881937');" title="윈린 - 페이지 이동">윈린</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685705');" title="당신은 날 가르치지 않았죠 - 페이지 이동">당신은 날 가르치지 않았죠</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427990);" title="Delete 재생">Delete</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4013611');" title="페일메이즈 - 페이지 이동">페일메이즈</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4013611');" title="페일메이즈 - 페이지 이동">페일메이즈</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685465');" title="DELETE - 페이지 이동">DELETE</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427977);" title="Fade Away 재생">Fade Away</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3128722');" title="MODN (모든) - 페이지 이동">MODN (모든)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3128722');" title="MODN (모든) - 페이지 이동">MODN (모든)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685461');" title="Fade Away - 페이지 이동">Fade Away</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427573);" title="Mom said kimchi stew is delicious. 재생">Mom said kimchi stew is delicious.</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088803');" title="아림 - 페이지 이동">아림</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088803');" title="아림 - 페이지 이동">아림</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685383');" title="엄마는 김치찌개가 맛있다고 하셨어 - 페이지 이동">엄마는 김치찌개가 맛있다고 하셨어</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427283);" title="Runnin' down the street 재생">Runnin' down the street</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3096012');" title="퓨플즈 (Pupilz) - 페이지 이동">퓨플즈 (Pupilz)</a>, <a href="javascript:melon.link.goArtistDetail('2905342');" title="Pipuh(파이퍼) - 페이지 이동">Pipuh(파이퍼)</a>, <a href="javascript:melon.link.goArtistDetail('2935807');" title="HYOI - 페이지 이동">HYOI</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3096012');" title="퓨플즈 (Pupilz) - 페이지 이동">퓨플즈 (Pupilz)</a>, <a href="javascript:melon.link.goArtistDetail('2905342');" title="Pipuh(파이퍼) - 페이지 이동">Pipuh(파이퍼)</a>, <a href="javascript:melon.link.goArtistDetail('2935807');" title="HYOI - 페이지 이동">HYOI</a></span>
# </div>
# <div class="wrap_atist" style="display:none;">
# <button class="button_icons etc more_down" data-control="dropdown" title="아티스트 더보기" type="button"><span class="none">아티스트명 더보기</span></button>
# <div class="atist_view" style="display:none;">
# <ul>
# <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('3096012');" title="퓨플즈 (Pupilz) 페이지 이동">퓨플즈 (Pupilz)</a></li>
# <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('2905342');" title="Pipuh(파이퍼) 페이지 이동">Pipuh(파이퍼)</a></li>
# <li><a class="ellipsis" href="javascript:melon.link.goArtistDetail('2935807');" title="HYOI 페이지 이동">HYOI</a></li>
# </ul>
# </div>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685335');" title="Runnin' down the street - 페이지 이동">Runnin' down the street</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426668);" title="동백 재생">동백</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3099934');" title="한 가 - 페이지 이동">한 가</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3099934');" title="한 가 - 페이지 이동">한 가</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685176');" title="동백 - 페이지 이동">동백</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426666);" title="너에게 재생">너에게</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088733');" title="전기승 - 페이지 이동">전기승</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088733');" title="전기승 - 페이지 이동">전기승</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685174');" title="너에게 - 페이지 이동">너에게</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426663);" title="몰라 재생">몰라</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3682868');" title="파스텔플레이버 - 페이지 이동">파스텔플레이버</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3682868');" title="파스텔플레이버 - 페이지 이동">파스텔플레이버</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685171');" title="몰라 - 페이지 이동">몰라</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426662);" title="듣는 건 너의 책임 재생">듣는 건 너의 책임</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088731');" title="듣는건너의책임 - 페이지 이동">듣는건너의책임</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088731');" title="듣는건너의책임 - 페이지 이동">듣는건너의책임</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685170');" title="듣는 건 너의 책임 - 페이지 이동">듣는 건 너의 책임</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426634);" title="우리의 겨울이었던 재생">우리의 겨울이었던</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088726');" title="새올 - 페이지 이동">새올</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088726');" title="새올 - 페이지 이동">새올</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685152');" title="우리의 겨울이었던 - 페이지 이동">우리의 겨울이었던</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38426155);" title="Call you my name (Feat Jae-ho) 재생">Call you my name (Feat Jae-ho)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088694');" title="syxc - 페이지 이동">syxc</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088694');" title="syxc - 페이지 이동">syxc</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685048');" title="Call you my name - 페이지 이동">Call you my name</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424491);" title="100% 재생">100%</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3612969');" title="TOVE - 페이지 이동">TOVE</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3612969');" title="TOVE - 페이지 이동">TOVE</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684706');" title="100% - 페이지 이동">100%</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <span class="bullet_icons age_19" title="19세 미만 청소년 이용불가"><span class="none">19금</span></span>
# <a href="javascript:melon.play.playSong('25260101',38424246);" title="Wrong Person, Right Timing 재생">Wrong Person, Right Timing</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3183877');" title="아이오웰 (Aiowell) - 페이지 이동">아이오웰 (Aiowell)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3183877');" title="아이오웰 (Aiowell) - 페이지 이동">아이오웰 (Aiowell)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684636');" title="Valentine - 페이지 이동">Valentine</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38419901);" title="I've chosen you 재생">I've chosen you</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('428460');" title="Master Class - 페이지 이동">Master Class</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('428460');" title="Master Class - 페이지 이동">Master Class</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11683671');" title="I've chosen you - 페이지 이동">I've chosen you</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38419904);" title="잠깐 멈춰 바라볼 때 재생">잠깐 멈춰 바라볼 때</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2746593');" title="승희 - 페이지 이동">승희</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2746593');" title="승희 - 페이지 이동">승희</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11683674');" title="잠깐 멈춰 바라볼 때 - 페이지 이동">잠깐 멈춰 바라볼 때</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424599);" title="Caution Tape (Feat. Jinee) (prod. by 1024) 재생">Caution Tape (Feat. Jinee) (prod. by 1024)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2758886');" title="JA!L - 페이지 이동">JA!L</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2758886');" title="JA!L - 페이지 이동">JA!L</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684730');" title="Better than that - 페이지 이동">Better than that</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38425161);" title="새벽 재생">새벽</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088598');" title="샛별 - 페이지 이동">샛별</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088598');" title="샛별 - 페이지 이동">샛별</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684907');" title="새벽 - 페이지 이동">새벽</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424802);" title="나방은 빛으로 뛰어든다 재생">나방은 빛으로 뛰어든다</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088557');" title="용칠 - 페이지 이동">용칠</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088557');" title="용칠 - 페이지 이동">용칠</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684784');" title="용칠이 곤충기 - 페이지 이동">용칠이 곤충기</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424644);" title="Moment 재생">Moment</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3201966');" title="The Beenong (더 비농) - 페이지 이동">The Beenong (더 비농)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3201966');" title="The Beenong (더 비농) - 페이지 이동">The Beenong (더 비농)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684741');" title="Moment - 페이지 이동">Moment</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424489);" title="KeshiA (feat. JUNGL$) 재생">KeshiA (feat. JUNGL$)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3871688');" title="huiAe - 페이지 이동">huiAe</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3871688');" title="huiAe - 페이지 이동">huiAe</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684704');" title="KeshiA - 페이지 이동">KeshiA</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424486);" title="아버지가 되었어요 재생">아버지가 되었어요</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('661591');" title="서상욱 - 페이지 이동">서상욱</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('661591');" title="서상욱 - 페이지 이동">서상욱</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684702');" title="아버지가 되었어요 - 페이지 이동">아버지가 되었어요</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424484);" title="제자리 재생">제자리</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088531');" title="여기, 배덕순 - 페이지 이동">여기, 배덕순</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088531');" title="여기, 배덕순 - 페이지 이동">여기, 배덕순</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684700');" title="제자리 - 페이지 이동">제자리</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424455);" title="Never Give Up 재생">Never Give Up</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2913047');" title="JUNE 53 - 페이지 이동">JUNE 53</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2913047');" title="JUNE 53 - 페이지 이동">JUNE 53</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684689');" title="Never Give Up - 페이지 이동">Never Give Up</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424454);" title="Airport 재생">Airport</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088509');" title="정민영 - 페이지 이동">정민영</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088509');" title="정민영 - 페이지 이동">정민영</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684688');" title="Airport - 페이지 이동">Airport</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424453);" title="기억할게요 재생">기억할게요</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2922492');" title="진선교 - 페이지 이동">진선교</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2922492');" title="진선교 - 페이지 이동">진선교</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684687');" title="기억할게요 - 페이지 이동">기억할게요</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424451);" title="Meaningless 재생">Meaningless</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2911504');" title="2weapon - 페이지 이동">2weapon</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2911504');" title="2weapon - 페이지 이동">2weapon</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684685');" title="Meaningless - 페이지 이동">Meaningless</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424450);" title="숨 (Remastered) 재생">숨 (Remastered)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2765353');" title="라네스터 (Lanester) - 페이지 이동">라네스터 (Lanester)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2765353');" title="라네스터 (Lanester) - 페이지 이동">라네스터 (Lanester)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684684');" title="RE.SCORFF #4 - 페이지 이동">RE.SCORFF #4</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424262);" title="그림자 (feat. 고무성) 재생">그림자 (feat. 고무성)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088491');" title="김무호 - 페이지 이동">김무호</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088491');" title="김무호 - 페이지 이동">김무호</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684640');" title="그림자 - 페이지 이동">그림자</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424242);" title="쉬운 이별 재생">쉬운 이별</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3135661');" title="문민철 - 페이지 이동">문민철</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3135661');" title="문민철 - 페이지 이동">문민철</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684635');" title="쉬운 이별 - 페이지 이동">쉬운 이별</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424225);" title="EASYYYY 재생">EASYYYY</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3458771');" title="SOYER - 페이지 이동">SOYER</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3458771');" title="SOYER - 페이지 이동">SOYER</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684624');" title="WAIT - 페이지 이동">WAIT</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424201);" title="졸업하는 너희에게 재생">졸업하는 너희에게</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2943571');" title="전지은 - 페이지 이동">전지은</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2943571');" title="전지은 - 페이지 이동">전지은</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684620');" title="졸업하는 너희에게 - 페이지 이동">졸업하는 너희에게</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38423608);" title="나를 찾아서 재생">나를 찾아서</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3679783');" title="고픔 - 페이지 이동">고픔</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3679783');" title="고픔 - 페이지 이동">고픔</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684520');" title="나를 찾아서 - 페이지 이동">나를 찾아서</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38420164);" title="DUPLICITY 재생">DUPLICITY</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3872813');" title="BOYO’SEAN - 페이지 이동">BOYO’SEAN</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3872813');" title="BOYO’SEAN - 페이지 이동">BOYO’SEAN</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11683749');" title="DUPLICITY - 페이지 이동">DUPLICITY</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38420070);" title="이제는 애기할게 재생">이제는 애기할게</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('1705353');" title="Normal puppy - 페이지 이동">Normal puppy</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1705353');" title="Normal puppy - 페이지 이동">Normal puppy</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11683727');" title="이제는 애기할게 - 페이지 이동">이제는 애기할게</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38419875);" title="Love for 재생">Love for</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('4088117');" title="요셉(Yoseph) - 페이지 이동">요셉(Yoseph)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('4088117');" title="요셉(Yoseph) - 페이지 이동">요셉(Yoseph)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11683664');" title="Love for - 페이지 이동">Love for</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424045);" title="엄마 재생">엄마</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2241043');" title="로키드 (Lokid) - 페이지 이동">로키드 (Lokid)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2241043');" title="로키드 (Lokid) - 페이지 이동">로키드 (Lokid)</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684585');" title="엄마 - 페이지 이동">엄마</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38424047);" title="바보같지 재생">바보같지</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2298856');" title="1DAY - 페이지 이동">1DAY</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2298856');" title="1DAY - 페이지 이동">1DAY</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11684586');" title="바보같지 - 페이지 이동">바보같지</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38418687);" title="썩은그물 재생">썩은그물</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('960069');" title="2단지 - 페이지 이동">2단지</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('960069');" title="2단지 - 페이지 이동">2단지</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11683248');" title="도처 - 페이지 이동">도처</a>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38416900);" title="blue [remastered] 재생">blue [remastered]</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2632952');" title="정우물 - 페이지 이동">정우물</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2632952');" title="정우물 - 페이지 이동">정우물</a></span>
# </div>
# </div>, <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11682922');" title="the blue - 페이지 이동">the blue</a>
# </div>
# </div>]

# %%
song_titles = []

# 모든 곡 정보를 포함하는 요소 선택
# songs = meta.select('.wrap_song_info')

# 각 곡 정보에서 곡 제목 추출
for song in song_list:
    title_element = song.select_one('.ellipsis.rank01 a')  # 곡 제목 선택
    if title_element:  # 요소가 존재할 경우
        song_titles.append(title_element.text.strip())  # 제목을 리스트에 추가

# 결과 출력
for title in song_titles:
    print(title)
# Out:
# 어떻게든 이별
# us
# 보통의 이야기
# 엔딩샷 (Ending Shot)
# If
# 잘자요
# 유영
# Our Time
# 첫눈에 반해버린 찐따
# 널 보고 싶지 않은 밤
# 우리의 사랑
# 당신은 날 가르치지 않았죠
# Delete
# Fade Away
# Mom said kimchi stew is delicious.
# Runnin' down the street
# 동백
# 너에게
# 몰라
# 듣는 건 너의 책임
# 우리의 겨울이었던
# Call you my name (Feat Jae-ho)
# 100%
# Wrong Person, Right Timing
# I've chosen you
# 잠깐 멈춰 바라볼 때
# Caution Tape (Feat. Jinee) (prod. by 1024)
# 새벽
# 나방은 빛으로 뛰어든다
# Moment
# KeshiA (feat. JUNGL$)
# 아버지가 되었어요
# 제자리
# Never Give Up
# Airport
# 기억할게요
# Meaningless
# 숨 (Remastered)
# 그림자 (feat. 고무성)
# 쉬운 이별
# EASYYYY
# 졸업하는 너희에게
# 나를 찾아서
# DUPLICITY
# 이제는 애기할게
# Love for
# 엄마
# 바보같지
# 썩은그물
# blue [remastered]

# %%
song_titles = []

# 모든 곡 정보를 포함하는 요소 선택
songs = meta.select('.wrap_song_info')

# 각 곡 정보에서 곡 제목 추출
for song in songs:
    title_element = song.select_one('.ellipsis.rank01 a')  # 곡 제목 선택
    if title_element:  # 요소가 존재할 경우
        title = title_element.text.strip()  # 제목 가져오기
        href = title_element['href']  # href 속성 가져오기
        song_titles.append((title, href))  # 제목과 href를 튜플로 리스트에 추가

# 결과 출력
for title, href in song_titles:
    print(f"곡 제목: {title}, 링크: {href}")

print(song)
# Out:
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('25260101',38427225);" title="어떻게든 이별 재생">어떻게든 이별</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('105031');" title="참깨와 솜사탕 - 페이지 이동">참깨와 솜사탕</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('105031');" title="참깨와 솜사탕 - 페이지 이동">참깨와 솜사탕</a></span>
# </div>
# </div>

# %%
# 데이터프레임 초기화
# columns = ['chartDate', 'rank', 'title', 'singer', 'album_name', 'release_date', 'genre', 'lyric', 'composer', 'lyricist', 'arranger']
# 곡 제목 title
# 가사 lylics
# 아티스트 artist
# 장르 ganre
# 발매일 date
# 좋아요 like
columns = ['title', 'artist', 'ganre', 'release_date', 'like_cnt', 'lylics']
song_data = pd.DataFrame(columns=columns)

# tqdm 라이브러리로 진행 상황 바 표시
for i, meta in tqdm(enumerate(song_list, 1), total=len(song_list), desc="Processing songs"):
    rank = i

    # 모든 곡 정보를 포함하는 요소 선택
    songs = meta.select('.wrap_song_info')

    # 각 곡 정보에서 곡 제목 추출
    for song in song_list:
        title_element = song.select_one('.ellipsis.rank01 a')  # 곡 제목 선택
        if title_element:  # 요소가 존재할 경우
            # song_titles.append(title_element.text.strip())  # 제목을 리스트에 추가
            title = title_element.text.strip()
            href = title_element['href']  # href 속성 가져오기
            # 정규 표현식을 사용하여 곡 ID 추출
            match = re.search(r"playSong\('(\d+)',(\d+)\)", href)
            # if match:
            song_id = match.group(2)  # 두 번째 그룹이 곡 ID
            song_url = 'https://www.melon.com/song/detail.htm?songId=' + song_id

            response = requests.get(song_url, params=params, headers=headers)
            soup = BeautifulSoup(response.text, 'html.parser')

            # 가수
            singer_html = soup.select('.wrap_info .artist a')
            singer_s = ', '.join([html['title'] for html in singer_html if html['title']]) if singer_html else 'Various Artists'

            # 앨범명
            # album_name = soup.select('.list dd')[0].get_text(strip=True)

            # 발매날짜
            release_date = soup.select('.list dd')[1].get_text(strip=True)

            # 장르
            genre = soup.select('.list dd')[2].get_text(strip=True)

            # 좋아요 
            # <span id="d_like_count" class="cnt">44</span>
            # like_cnt = soup.select('.cnt').get_text(strip=True)

            # 예시 코드
            like_count_element = meta.select_one('#d_like_count')  # ID로 요소 선택
            if like_count_element:  # 요소가 존재할 경우
                like_cnt = like_count_element.text.strip()  # 텍스트 가져오기 및 공백 제거
            else:
                like_cnt = 0


            # 가사
            lyric = '없음'
            lyric_html = soup.select_one('.section_lyric .wrap_lyric .lyric')
            if lyric_html:
                lyric = lyric_html.get_text(strip=True, separator='\n')

            row = pd.Series([title, singer_s, genre, release_date, like_cnt,  lyric], index=song_data.columns)
            song_data = pd.concat([song_data, pd.DataFrame([row])], ignore_index=True)

            # 1초에서 5초 사이의 랜덤한 시간 선택
            random_sleep_time = random.uniform(1, 5)
            time.sleep(random_sleep_time)  # IP 차단 방지용 랜덤한 시간 동안 대기
# Out:
# Processing songs: 100%|██████████| 100/100 [4:29:29<00:00, 161.69s/it]

# %%
song_data
# Out:
#                   title       artist           ganre release_date like_cnt  \
# 0               어떻게든 이별      참깨와 솜사탕       발라드, 인디음악   2025.01.07        0
# 1               어떻게든 이별      참깨와 솜사탕       발라드, 인디음악   2025.01.07        0
# 2                    us    잭킹콩 (JKC)  R&B/Soul, 인디음악   2025.01.07        0
# 3               보통의 이야기           소보    인디음악, 포크/블루스   2025.01.07        0
# 4     엔딩샷 (Ending Shot)   정가이 (와인루프)       발라드, 인디음악   2025.01.07        0
# ...                 ...          ...             ...          ...      ...
# 4996           Love for   요셉(Yoseph)      인디음악, 록/메탈   2025.01.06        0
# 4997                 엄마  로키드 (Lokid)       발라드, 인디음악   2025.01.05        0
# 4998               바보같지         1DAY      랩/힙합, 인디음악   2025.01.05        0
# 4999               썩은그물          2단지    인디음악, 포크/블루스   2025.01.05        0
# 5000  blue [remastered]          정우물      인디음악, 록/메탈   2025.01.05        0
#
#                                                  lylics
# 0     난 왜\n그 미움까지 그리운 걸까\n그토록 미웠던 끝 모습을 꺼내보고 말야\n그때 ...
# 1     난 왜\n그 미움까지 그리운 걸까\n그토록 미웠던 끝 모습을 꺼내보고 말야\n그때 ...
# 2     I’ll make sure you feel safe in my shoulders\n...
# 3     헝클어져있던 주머니속 실타래들\n널부러져있던 깨진 기억의 파편들\n상처들\n찾으려해...
# 4     믿을 수 없어 네가 내 곁에 없단 게\n우린 죽도록 사랑했는데\n널 다시는 볼 수 ...
# ...                                                 ...
# 4996  What do you love for?\nI mean why?\nDo you lov...
# 4997  ‘엄마 사랑해’라는 말은\n왜 이렇게 낯간지러운지\n세상에서 제일 소중한 내 편인데...
# 4998  어? 시간이 이렇게나 됐어\n어쩌다 내 나이가 벌써\n난 아직 운전도 못하고\n직업...
# 4999  어제의 꿈속이라면 건져내기 좋은데\n등 푸른 지옥이라도 달려오면 어쩌나\n강가에 비...
# 5000  순수했었던 그 시절엔\n어떤 색깔만 봐도 특별했던\n그런 나를 보면 참 슬퍼요\n외...
#
# [5001 rows x 6 columns]

# %%
import datetime

#데이터 프레임 저장
now = datetime.datetime.now()
address = 'C:\\Two_Kim_and_One_Lee\\data\\'
# os.chdir("./data")
# song_data.to_csv(address, index=False, encoding='utf-8-sig')
song_data.to_csv(path_or_buf=address+'melon.csv')
# song_data.to_csv('melon{}_{}.csv'.format(search,now.strftime('%Y%m%d_%H시%M분%S초')),encoding='utf-8-sig',index=False)

# %%
song_dt = pd.read_csv("./data/melon.csv")

# %%
song_dt
# Out:
#       Unnamed: 0              title       artist           ganre release_date  \
# 0              0            어떻게든 이별      참깨와 솜사탕       발라드, 인디음악   2025.01.07
# 1              1            어떻게든 이별      참깨와 솜사탕       발라드, 인디음악   2025.01.07
# 2              2                 us    잭킹콩 (JKC)  R&B/Soul, 인디음악   2025.01.07
# 3              3            보통의 이야기           소보    인디음악, 포크/블루스   2025.01.07
# 4              4  엔딩샷 (Ending Shot)   정가이 (와인루프)       발라드, 인디음악   2025.01.07
# ...          ...                ...          ...             ...          ...
# 4996        4996           Love for   요셉(Yoseph)      인디음악, 록/메탈   2025.01.06
# 4997        4997                 엄마  로키드 (Lokid)       발라드, 인디음악   2025.01.05
# 4998        4998               바보같지         1DAY      랩/힙합, 인디음악   2025.01.05
# 4999        4999               썩은그물          2단지    인디음악, 포크/블루스   2025.01.05
# 5000        5000  blue [remastered]          정우물      인디음악, 록/메탈   2025.01.05
#
#       like_cnt                                             lylics
# 0            0  난 왜\n그 미움까지 그리운 걸까\n그토록 미웠던 끝 모습을 꺼내보고 말야\n그때 ...
# 1            0  난 왜\n그 미움까지 그리운 걸까\n그토록 미웠던 끝 모습을 꺼내보고 말야\n그때 ...
# 2            0  I’ll make sure you feel safe in my shoulders\n...
# 3            0  헝클어져있던 주머니속 실타래들\n널부러져있던 깨진 기억의 파편들\n상처들\n찾으려해...
# 4            0  믿을 수 없어 네가 내 곁에 없단 게\n우린 죽도록 사랑했는데\n널 다시는 볼 수 ...
# ...        ...                                                ...
# 4996         0  What do you love for?\nI mean why?\nDo you lov...
# 4997         0  ‘엄마 사랑해’라는 말은\n왜 이렇게 낯간지러운지\n세상에서 제일 소중한 내 편인데...
# 4998         0  어? 시간이 이렇게나 됐어\n어쩌다 내 나이가 벌써\n난 아직 운전도 못하고\n직업...
# 4999         0  어제의 꿈속이라면 건져내기 좋은데\n등 푸른 지옥이라도 달려오면 어쩌나\n강가에 비...
# 5000         0  순수했었던 그 시절엔\n어떤 색깔만 봐도 특별했던\n그런 나를 보면 참 슬퍼요\n외...
#
# [5001 rows x 7 columns]

# %%
song_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    5001 non-null   int64
#  1   title         5001 non-null   object
#  2   artist        5001 non-null   object
#  3   ganre         5001 non-null   object
#  4   release_date  5001 non-null   object
#  5   like_cnt      5001 non-null   int64
#  6   lylics        5001 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 273.6+ KB

# %%
# HTML 태그 제거 함수
def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

# %%
# 데이터프레임의 'lylics' 열에 적용
song_dt['lylics'] = song_dt['lylics'].apply(remove_html_tags)

# 줄 바꿈 문자 제거
song_dt['lyrics'] = song_dt['lylics'].str.replace('\n', '', regex=False)

# %%
song_dt.head()
# Out:
#    Unnamed: 0              title      artist           ganre release_date  \
# 0           0            어떻게든 이별     참깨와 솜사탕       발라드, 인디음악   2025.01.07
# 1           1            어떻게든 이별     참깨와 솜사탕       발라드, 인디음악   2025.01.07
# 2           2                 us   잭킹콩 (JKC)  R&B/Soul, 인디음악   2025.01.07
# 3           3            보통의 이야기          소보    인디음악, 포크/블루스   2025.01.07
# 4           4  엔딩샷 (Ending Shot)  정가이 (와인루프)       발라드, 인디음악   2025.01.07
#
#    like_cnt                                             lylics  \
# 0         0  난 왜\n그 미움까지 그리운 걸까\n그토록 미웠던 끝 모습을 꺼내보고 말야\n그때 ...
# 1         0  난 왜\n그 미움까지 그리운 걸까\n그토록 미웠던 끝 모습을 꺼내보고 말야\n그때 ...
# 2         0  I’ll make sure you feel safe in my shoulders\n...
# 3         0  헝클어져있던 주머니속 실타래들\n널부러져있던 깨진 기억의 파편들\n상처들\n찾으려해...
# 4         0  믿을 수 없어 네가 내 곁에 없단 게\n우린 죽도록 사랑했는데\n널 다시는 볼 수 ...
#
#                                               lyrics
# 0  난 왜그 미움까지 그리운 걸까그토록 미웠던 끝 모습을 꺼내보고 말야그때 그렇게 있지...
# 1  난 왜그 미움까지 그리운 걸까그토록 미웠던 끝 모습을 꺼내보고 말야그때 그렇게 있지...
# 2  I’ll make sure you feel safe in my shoulderswh...
# 3  헝클어져있던 주머니속 실타래들널부러져있던 깨진 기억의 파편들상처들찾으려해 철이없던 ...
# 4  믿을 수 없어 네가 내 곁에 없단 게우린 죽도록 사랑했는데널 다시는 볼 수 없다는 ...

# %%
song_dt = song_dt.drop(columns=['lylics'])

# %%
song_dt
# Out:
#       Unnamed: 0              title       artist           ganre release_date  \
# 0              0            어떻게든 이별      참깨와 솜사탕       발라드, 인디음악   2025.01.07
# 1              1            어떻게든 이별      참깨와 솜사탕       발라드, 인디음악   2025.01.07
# 2              2                 us    잭킹콩 (JKC)  R&B/Soul, 인디음악   2025.01.07
# 3              3            보통의 이야기           소보    인디음악, 포크/블루스   2025.01.07
# 4              4  엔딩샷 (Ending Shot)   정가이 (와인루프)       발라드, 인디음악   2025.01.07
# ...          ...                ...          ...             ...          ...
# 4996        4996           Love for   요셉(Yoseph)      인디음악, 록/메탈   2025.01.06
# 4997        4997                 엄마  로키드 (Lokid)       발라드, 인디음악   2025.01.05
# 4998        4998               바보같지         1DAY      랩/힙합, 인디음악   2025.01.05
# 4999        4999               썩은그물          2단지    인디음악, 포크/블루스   2025.01.05
# 5000        5000  blue [remastered]          정우물      인디음악, 록/메탈   2025.01.05
#
#       like_cnt                                             lyrics
# 0            0  난 왜그 미움까지 그리운 걸까그토록 미웠던 끝 모습을 꺼내보고 말야그때 그렇게 있지...
# 1            0  난 왜그 미움까지 그리운 걸까그토록 미웠던 끝 모습을 꺼내보고 말야그때 그렇게 있지...
# 2            0  I’ll make sure you feel safe in my shoulderswh...
# 3            0  헝클어져있던 주머니속 실타래들널부러져있던 깨진 기억의 파편들상처들찾으려해 철이없던 ...
# 4            0  믿을 수 없어 네가 내 곁에 없단 게우린 죽도록 사랑했는데널 다시는 볼 수 없다는 ...
# ...        ...                                                ...
# 4996         0  What do you love for?I mean why?Do you love me...
# 4997         0  ‘엄마 사랑해’라는 말은왜 이렇게 낯간지러운지세상에서 제일 소중한 내 편인데어른이 ...
# 4998         0  어? 시간이 이렇게나 됐어어쩌다 내 나이가 벌써난 아직 운전도 못하고직업 따윈 없어...
# 4999         0  어제의 꿈속이라면 건져내기 좋은데등 푸른 지옥이라도 달려오면 어쩌나강가에 비췄던 나...
# 5000         0  순수했었던 그 시절엔어떤 색깔만 봐도 특별했던그런 나를 보면 참 슬퍼요외로움도 많았...
#
# [5001 rows x 7 columns]
